# %% [markdown]
# # Ollama Beispiele & Prompts

# %% [markdown]
# ## Was ist ein Prompt?
# Ein Prompt ist eine strukturierte Eingabe oder Anweisung an ein KI-Modell (wie Llama), die eine bestimmte Ausgabe oder Antwort auslösen soll.
#
# ## Arten von Prompts
#
# ### 1. Einfacher Prompt
# * Einzelne, direkte Frage
# * Beispiel: `"Was ist der Unterschied zwischen einer Universität und einer Fachhochschule in Deutschland?"`

# %%
import ollama

# Beispiel 1: Einfacher Chat
def einfacher_chat(model_name):
    messages = [
        {'role': 'user', 'content': 'Was ist der Unterschied zwischen einer Universität und einer Fachhochschule in Deutschland?'}
    ]
    print("Frage:")
    print(messages[0]['content'])
    print("\nEinfache Chat-Antwort:")
    response = ollama.chat(model=model_name, messages=messages)
    print(response['message']['content'])
    print("\n" + "="*50 + "\n")

# %% [markdown]
# ### 2. Konversations-Prompt
# * Mehrere aufeinanderfolgende Nachrichten
# * Im Falle von Ollama enthält eine Prompt Rollenzuweisungen (`user` und `assistant`)
# * Baut Kontext über mehrere Interaktionen auf

# %%
# Beispiel 2: Mehrteilige Konversation
def mehrteilige_konversation(model_name):
    messages = [
        {'role': 'user', 'content': 'Ich möchte eine Bachelorarbeit schreiben. Kannst du mir dabei helfen?'},
        {'role': 'assistant', 'content': 'Natürlich! Ich kann Ihnen gerne bei Ihrer Bachelorarbeit helfen. Womit genau brauchen Sie Unterstützung? Möchten Sie Hilfe bei der Themenfindung, der Strukturierung oder der Recherche?'},
        {'role': 'user', 'content': 'Ich brauche Hilfe bei der Strukturierung. Wie sollte eine Bachelorarbeit aufgebaut sein?'},
        {'role': 'assistant', 'content': 'Eine typische Struktur für eine Bachelorarbeit umfasst folgende Teile: Titelblatt, Inhaltsverzeichnis, Einleitung, Hauptteil (Theorie, Methodik, Ergebnisse), Diskussion, Fazit, Literaturverzeichnis und ggf. Anhang. Die Einleitung sollte das Thema vorstellen, die Forschungsfrage präsentieren und einen Überblick über die Arbeit geben. Der Hauptteil bildet den Kern der Arbeit und sollte logisch gegliedert sein. Im Fazit werden die wichtigsten Erkenntnisse zusammengefasst und ein Ausblick gegeben.'},
        {'role': 'user', 'content': 'Danke! Wie lang sollte die Einleitung ungefähr sein?'}
    ]
    print("Mehrteilige Konversation:")
    for message in messages:
        if message['role'] == 'user':
            print(f"\nFrage: {message['content']}")
        elif message['role'] == 'assistant':
            print(f"Antwort: {message['content']}")
    
    print("\nLetzte Antwort der mehrteiligen Konversation:")
    response = ollama.chat(model=model_name, messages=messages)
    print(response['message']['content'])
    print("\n" + "="*50 + "\n")

# %% [markdown]
# ### 3. Parametrisierter Prompt
# * Enthält spezifische Anforderungen
# * Beispiel: `"Schreibe eine kurze Zusammenfassung (ca. 100 Wörter) über..."`

# %%
# Beispiel 3: Generieren mit benutzerdefinierten Parametern
def generieren_mit_parametern(model_name):
    prompt = "Schreibe eine kurze Zusammenfassung (ca. 100 Wörter) über die Geschichte der Carl von Ossietzky Universität Oldenburg."
    print("Aufforderung:")
    print(prompt)
    print("\nGenerierte Zusammenfassung mit benutzerdefinierten Parametern:")
    response = ollama.generate(model_name, prompt=prompt)
    print(response['response'])
    print("\n" + "="*50 + "\n")

# %%
# Alle Beispiele ausführen
einfacher_chat(model_name="llama3:8b")
mehrteilige_konversation(model_name="llama3:8b")
generieren_mit_parametern(model_name="llama3:8b")
# Out:
# Frage:
# Was ist der Unterschied zwischen einer Universität und einer Fachhochschule in Deutschland?
#
# Einfache Chat-Antwort:
# In Germany, a university (Deutsche Hochschule) and a University of Applied Sciences (Fachhochschule) are two different types of higher education institutions. Here's the main difference:
#
# **Universities (Deutsche Hochschule):**
#
# 1. Research-oriented: Universities focus on basic research and theoretical foundations in various fields, such as natural sciences, humanities, social sciences, and engineering.
# 2. Academic programs: They offer a wide range of academic programs at the bachelor's and master's levels, including traditional disciplines like philosophy, history, and languages.
# 3. Interdisciplinary approaches: Universities often take an interdisciplinary approach to education and research, combining multiple fields of study.
# 4. Higher-level degrees: They typically award higher-level degrees, such as Diplom, Magister, or Dr., which are recognized throughout Europe.
#
# **University of Applied Sciences (Fachhochschule):**
#
# 1. Practice-oriented: Fachhochschulen focus on applied sciences and practical problem-solving in fields like technology, business, health care, and social services.
# 2. Professional programs: They offer professional programs at the bachelor's and master's levels, often with a strong emphasis on vocational training and industry partnerships.
# 3. Practical skills: Fachhochschulen prioritize the development of practical skills and knowledge that are directly applicable to specific industries or professions.
# 4. Vocationally oriented degrees: They typically award vocationally oriented degrees, such as Bachelor of Science (B.Sc.) or Master of Science (M.Sc.), which are recognized by employers.
#
# In summary:
#
# * Universities focus on theoretical foundations and research in a wide range of fields.
# * University of Applied Sciences (Fachhochschulen) concentrate on practical problem-solving and professional training in specific industries or professions.
#
# It's worth noting that the boundaries between universities and Fachhochschulen are blurring, and some institutions are offering programs that combine both theoretical and practical approaches. Additionally, the Bologna Process has led to a harmonization of degree structures across Europe, making it easier for students to transfer between institutions.
#
# ==================================================
#
# Mehrteilige Konversation:
#
# Frage: Ich möchte eine Bachelorarbeit schreiben. Kannst du mir dabei helfen?
# Antwort: Natürlich! Ich kann Ihnen gerne bei Ihrer Bachelorarbeit helfen. Womit genau brauchen Sie Unterstützung? Möchten Sie Hilfe bei der Themenfindung, der Strukturierung oder der Recherche?
#
# Frage: Ich brauche Hilfe bei der Strukturierung. Wie sollte eine Bachelorarbeit aufgebaut sein?
# Antwort: Eine typische Struktur für eine Bachelorarbeit umfasst folgende Teile: Titelblatt, Inhaltsverzeichnis, Einleitung, Hauptteil (Theorie, Methodik, Ergebnisse), Diskussion, Fazit, Literaturverzeichnis und ggf. Anhang. Die Einleitung sollte das Thema vorstellen, die Forschungsfrage präsentieren und einen Überblick über die Arbeit geben. Der Hauptteil bildet den Kern der Arbeit und sollte logisch gegliedert sein. Im Fazit werden die wichtigsten Erkenntnisse zusammengefasst und ein Ausblick gegeben.
#
# Frage: Danke! Wie lang sollte die Einleitung ungefähr sein?
#
# Letzte Antwort der mehrteiligen Konversation:
# Die Länge der Einleitung variiert je nach Autor und Universität, aber eine gute Regel ist, dass sie etwa 5-10% der Gesamt-Länge der Arbeit ausmacht. Das bedeutet, wenn Ihre Bachelorarbeit insgesamt etwa 20 Seiten lang sein wird, sollte die Einleitung etwa 1-2 Seiten lang sein.
#
# In der Einleitung sollten Sie:
#
# * Einen Überblick über das Thema und die Forschungsfrage geben
# * Die Bedeutung des Themas für die Fachwelt und die Praxis erläutern
# * Ihre Forschungsfrage präsentieren und die Hypothesen oder Ansätze darstellen, die Sie verfolgen werden
#
# Stellen Sie sich vor, dass die Einleitung ein "Vorwort" zur Arbeit ist. Sie sollten den Leser auf das zu erwartende Thema einstimmen und ihn auf die Forschungsfrage und die Methode vorbereiten.
#
# Erinnern Sie sich an: Die Einleitung sollte nicht den Kern der Arbeit ausmachen, sondern vielmehr als Übersichtsseite dienen!
#
# ==================================================
#
# Aufforderung:
# Schreibe eine kurze Zusammenfassung (ca. 100 Wörter) über die Geschichte der Carl von Ossietzky Universität Oldenburg.
#
# Generierte Zusammenfassung mit benutzerdefinierten Parametern:
# Die Carl-von-Ossietzky-Universität Oldenburg ist eine staatliche Hochschule in Norddeutschland, die im Jahr 1949 gegründet wurde. Der Namensgeber Carl von Ossietzky war ein deutscher Pazifist und Friedensaktivist, der 1935 den Nobelpreis für Literatur erhielt. In den 1950er Jahren begann die Universität ihre Entwicklung mit den Fakultäten Rechtswissenschaft, Soziologie und Psychologie. Im Laufe der Jahre wuchs die Universität kontinuierlich an, neue Fakultäten wie die Philosophie, Geschichte und Politikwissenschaft wurden gegründet. Heute zählt die Carl-von-Ossietzky-Universität Oldenburg mit etwa 9.000 Studenten zu den größeren Hochschulen in Deutschland. Die Universität ist bekannt für ihre Schwerpunkte auf Wirtschaftswissenschaften, Rechtswissenschaft und Soziologie, daneben gibt es auch Forschungsbereiche wie die Umwelt- und Energieforschung. Die Universität versteht sich als ein Ort der Kritik und Reflexion, der den Studierenden eine breite Ausbildung in wissenschaftlichen, ethischen und sozialen Aspekten bietet.
#
# ==================================================
#
# Frage:
# Erkläre das deutsche Notensystem an Universitäten.
#
# Streaming-Antwort:
# The German note system at universities!
#
# In Germany, Austria, and some other European countries, a specific notation system is used to indicate the quality of student performance on exams and assignments. This system is commonly known as the "German note system" or "Notensystem".
#
# Here's how it works:
#
# 1. **Note values**: The German note system uses five levels:
# 	* 1.0 (Sehr gut, very good): Excellent work, almost perfect.
# 	* 2.0 (Gut, good): Very satisfactory, with some minor mistakes.
# 	* 3.0 (Befriedigend, satisfactory): Average, meets the minimum requirements.
# 	* 4.0 (Outreichend, passable): Sufficient, but not outstanding.
# 	* 5.0 (Unzureichend, insufficient): Unsatisfactory, requires significant improvement.
# 2. **Note modifiers**: To provide more detail, additional notation can be used:
# 	* "+" or "-" for small deviations from the main note value (e.g., 1.7 instead of 1.0).
# 	* "mit Auszeichnung" (with distinction) for exceptional work (usually only awarded at universities with a high reputation).
#
# Some general rules to keep in mind:
#
# * The majority of universities use this system, but some might have slight variations.
# * Not all courses or programs may use the German note system; check your specific university's regulations.
# * When comparing notes across different universities or institutions, you should consider any potential differences in grading scales.
#
# Now that you know the basics of the German note system, you'll be better equipped to navigate the world of higher education in Germany and beyond!
# ==================================================

# %% [markdown]
# ## Struktur
# * `role`: Definiert den Sprecher (`user` oder `assistant`)
# * `content`: Enthält den eigentlichen Inhalt der Nachricht
# * `messages`: Liste von Nachrichtenobjekten für Konversationen
#
# ## Anwendungsmöglichkeiten
# * Einzelne Fragen und Antworten
# * Mehrstufige Dialoge
# * Spezifische Textgenerierung
# * Streaming-Antworten
#
# ## Best Practices
# * Klare, präzise Formulierungen
# * Spezifische Längenangaben wenn nötig
# * Strukturierte Konversationsführung

# %%
# Alle Beispiele ausführen mit anderem Model
einfacher_chat(model_name="llama3:70b")
mehrteilige_konversation(model_name="llama3:70b")
generieren_mit_parametern(model_name="llama3:70b")
# Out:
# Frage:
# Was ist der Unterschied zwischen einer Universität und einer Fachhochschule in Deutschland?
#
# Einfache Chat-Antwort:
# In Deutschland gibt es zwei Arten von Hochschulen: Universitäten und Fachhochschulen. Beide bieten akademische Ausbildungen an, aber sie haben unterschiedliche Schwerpunkte, Ziele und Strukturen.
#
# **Universitäten**
#
# Universitäten sind traditionelle Forschungsuniversitäten, die sich auf wissenschaftliche Grundlagenforschung und Theoriebildung konzentrieren. Sie bieten Studiengänge in verschiedenen Fachbereichen an, wie z.B. Naturwissenschaften, Ingenieurwissenschaften, Geisteswissenschaften, Sozialwissenschaften und Medizin.
#
# Die Hauptmerkmale von Universitäten sind:
#
# * Fokus auf Grundlagenforschung und Theoriebildung
# * Breites Fächerspektrum mit vielen Studiengängen
# * Promotion (Doktorat) möglich
# * Meistens größere Einrichtungen mit einer breiten Palette an Forschungsinstitutionen und -zentren
#
# **Fachhochschulen**
#
# Fachhochschulen, auch als Hochschulen für Angewandte Wissenschaften bezeichnet, konzentrieren sich auf die Anwendung von Wissen in der Praxis. Sie bieten Studiengänge an, die direkt auf den Bedarf der Wirtschaft und Gesellschaft ausgerichtet sind.
#
# Die Hauptmerkmale von Fachhochschulen sind:
#
# * Fokus auf angewandte Forschung und Entwicklung
# * Enge Verbindung zur Wirtschaft und Gesellschaft
# * Praxisorientierte Studiengänge mit einem hohen Anteil an Projektarbeit und Praktika
# * Meistens kleinere Einrichtungen mit einer stärkeren Ausrichtung auf bestimmte Fachbereiche
#
# **Hauptunterschiede**
#
# Die Hauptunterschiede zwischen Universitäten und Fachhochschulen sind:
#
# * Fokus: Universitäten auf Grundlagenforschung, Fachhochschulen auf angewandte Forschung und Entwicklung
# * Studiengänge: Universitäten bieten ein breiteres Fächerspektrum an, während Fachhochschulen sich auf bestimmte Fachbereiche konzentrieren
# * Promotion: Universitäten bieten Promotionsmöglichkeiten an, während Fachhochschulen meistens keine Doktoratprogramme haben
#
# Es ist jedoch zu beachten, dass es Überschneidungen zwischen beiden gibt und einige Hochschulen Merkmale beider Arten aufweisen.
#
# ==================================================
#
# Mehrteilige Konversation:
#
# Frage: Ich möchte eine Bachelorarbeit schreiben. Kannst du mir dabei helfen?
# Antwort: Natürlich! Ich kann Ihnen gerne bei Ihrer Bachelorarbeit helfen. Womit genau brauchen Sie Unterstützung? Möchten Sie Hilfe bei der Themenfindung, der Strukturierung oder der Recherche?
#
# Frage: Ich brauche Hilfe bei der Strukturierung. Wie sollte eine Bachelorarbeit aufgebaut sein?
# Antwort: Eine typische Struktur für eine Bachelorarbeit umfasst folgende Teile: Titelblatt, Inhaltsverzeichnis, Einleitung, Hauptteil (Theorie, Methodik, Ergebnisse), Diskussion, Fazit, Literaturverzeichnis und ggf. Anhang. Die Einleitung sollte das Thema vorstellen, die Forschungsfrage präsentieren und einen Überblick über die Arbeit geben. Der Hauptteil bildet den Kern der Arbeit und sollte logisch gegliedert sein. Im Fazit werden die wichtigsten Erkenntnisse zusammengefasst und ein Ausblick gegeben.
#
# Frage: Danke! Wie lang sollte die Einleitung ungefähr sein?
#
# Letzte Antwort der mehrteiligen Konversation:
# Die Länge der Einleitung kann je nach Fachbereich und Arbeit variieren, aber generell sollte sie etwa 5-10% des gesamten Umfangs der Bachelorarbeit ausmachen. Das bedeutet, wenn Ihre Arbeit insgesamt etwa 30-40 Seiten lang ist, sollte die Einleitung etwa 1,5-4 Seiten umfassen.
#
# In der Einleitung sollten Sie das Thema vorstellen, den Hintergrund und Kontext beschreiben, die Forschungsfrage oder -problem präsentieren und einen Überblick über die Arbeit geben. Außerdem sollten Sie darin auch die Zielsetzung, den Aufbau und die Methodik Ihrer Arbeit ankündigen.
#
# Es ist wichtig, dass die Einleitung interessant und einleitend ist, aber nicht zu langatmig oder zu detailliert. Sie sollte den Leser neugierig machen und ihn dazu animieren, weiterzulesen.
#
# ==================================================
#
# Aufforderung:
# Schreibe eine kurze Zusammenfassung (ca. 100 Wörter) über die Geschichte der Carl von Ossietzky Universität Oldenburg.
#
# Generierte Zusammenfassung mit benutzerdefinierten Parametern:
# Die Carl von Ossietzky Universität Oldenburg hat ihre Wurzeln in der 1793 gegründeten oldenburgischen Lehrerbildungsanstalt. Im Jahr 1882 wurde die Anstalt zur Präparandenanstalt erweitert und 1929 zum Pädagogischen Institut umgewandelt. Nach dem Zweiten Weltkrieg folgte 1953 die Gründung der Pädagogischen Hochschule Oldenburg, die 1973 in die Universität Oldenburg überführt wurde. Seit 1991 trägt die Universität den Namen des Friedensnobelpreisträgers Carl von Ossietzky, um seine Verdienste um die Demokratie und Menschenrechte zu ehren. Heute ist die Carl von Ossietzky Universität Oldenburg eine moderne, forschungsorientierte Universität mit rund 12.000 Studierenden und einer breiten Palette an Studiengängen in den Natur-, Sozial- und Geisteswissenschaften.
#
# ==================================================
#
# Frage:
# Erkläre das deutsche Notensystem an Universitäten.
#
# Streaming-Antwort:
# What a great topic!
#
# The German notation system, also known as the "Solmization System," is a way of assigning syllables to musical notes in order to facilitate singing and sight-reading. It's widely used in Germany, Austria, Switzerland, and other European countries. Here's an explanation:
#
# **The Basics:**
#
# In the German notation system, each note has a specific syllable associated with it. The seven natural notes (A, B, C, D, E, F, G) are assigned the following syllables:
#
# 1. A - La
# 2. B - Si
# 3. C - Do
# 4. D - Ra
# 5. E - Mi
# 6. F - Fa
# 7. G - Sol
#
# **Accidentals (Sharps and Flats):**
#
# When a note is sharp (#), the syllable is pronounced with an "i" at the end (e.g., A# = La-i, C# = Do-i). When a note is flat (b), the syllable is pronounced with an "e" at the end (e.g., Ab = La-e, Eb = Mi-e).
#
# **Enharmonic Equivalents:**
#
# Notes that are enharmonic equivalents (i.e., have the same pitch but different letter names) share the same syllable. For example:
#
# * A# and Bb are both pronounced as "La-i"
# * C# and Db are both pronounced as "Do-i"
#
# **Benefits:**
#
# The German notation system has several advantages:
#
# 1. **Improved sight-reading:** By using specific syllables for each note, singers can more easily recognize intervals and relationships between notes.
# 2. **Enhanced pitch recognition:** The system helps develop a strong sense of pitch, making it easier to sing in tune.
# 3. **Facilitated learning:** The syllable system allows students to learn music more quickly, as they can focus on the sound and feel of the music rather than just reading notes.
#
# **Universities:**
#
# Many universities in Germany, Austria, Switzerland, and other European countries teach music theory and singing using the German notation system. It's an integral part of their music curricula, from undergraduate programs to graduate studies.
#
# In summary, the German notation system is a valuable tool for musicians, offering a unique approach to learning and performing music. Its widespread use in European universities is a testament to its effectiveness in fostering musical understanding and skill.
# ==================================================
